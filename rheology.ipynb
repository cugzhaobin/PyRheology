# %% [markdown]
# # Pow law rheology

# %%
import rheology
import numpy as np
import pandas

rock = pandas.read_csv('rock.csv')
rock
# Out:
#            name             A     n  d    m  Coh     r          Q         V  \
# 0        HK03dd  1.100000e+05  3.50  0  0.0    0  0.00   530000.0  0.000018
# 1        HK03dw  1.600000e+03  3.50  0  0.0    0  1.20   520000.0  0.000022
# 2        HK03gd  1.500000e+09  1.00  0  3.0    0  0.00   375000.0  0.000010
# 3        HK03gw  2.500000e+07  1.00  0  3.0    0  1.00   375000.0  0.000020
# 4    HK03disGBS  6.500000e+03  3.50  0  2.0    0  0.00   400000.0  0.000000
# 5   HZK11disGBS  6.310000e+04  2.90  0  0.7    0  0.00   445000.0  0.000000
# 6        MK00dw  1.584800e+03  3.00  0  0.0    0  0.98   470000.0  0.000020
# 7        MK00gw  5.011870e+04  1.00  0  3.0    0  1.00   295000.0  0.000020
# 8          FJ06  2.000000e+10  1.40  0  3.0    0  0.00   484000.0  0.000000
# 9         KJ03d  1.260000e+06  3.00  0  0.0    0  0.00  5100000.0  0.000014
# 10        KJ03w  7.943282e+02  3.00  0  1.2    0  1.20   470000.0  0.000024
# ...

# %% [markdown]
# # Hirth and Kohlstedt, 2003, dry olivine, dislocation creep
# ## HK03dd

# %%
i      = 0
T      = np.arange(600,1200)+273
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], rock.d[i], rock.m[i], rock.Coh[i], 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
# Out:
# 1.0 1.0

# %% [markdown]
# # Hirth and Kohlstedt, 2003, wet olivine, dislocation creep
# HK03dw

# %%
i      = 1
T      = np.arange(600,1200)+273
strain = 1e-12
Coh    = 1000
rhe    = rheology.flow_law(rock.A[i], rock.n[i], rock.d[i], rock.m[i], Coh, 
                           rock.r[i], rock.Q[i], 0, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
#rhe.plot_T_stress(T, rhe.GetSigma())
# Out:
# 1000 1.0

# %% [markdown]
# # Hirth and Kohlstedt, 2003, dry olivine, diffusion creep

# %%
i      = 2
rock.iloc[2]
T      = np.arange(600,1200)+273
d      = 10e3
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], rock.Coh[i], 
                           rock.r[i], rock.Q[i], 0, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
# Out:
# 1.0 10000.0

# %% [markdown]
# # Hirth and Kohlstedt, 2003, wet olivine, diffusion creep

# %%
i      = 3
rock.iloc[i]
T      = np.arange(600,1200)+273
d      = 10e3
Coh    = 1000
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], 1000, 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
# Out:
# 1000 10000.0

# %% [markdown]
# # Hirth and Kohlstedt, 2003, dry olivine, dis-GBS
# HK03disGBS

# %%
i      = 3
rock.iloc[i]
T      = np.arange(600,1200)+273
d      = 10e3
Coh    = 1
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], Coh, 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
# Out:
# 1 10000.0

# %% [markdown]
# # Hirth, Teyssier and Dunlap, 2001, quartzite

# %%
i      = 15
rock.iloc[i]
T      = np.arange(600,1200)+273
d      = 0
Coh    = 1000
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], Coh, 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
#rhe.plot_T_stress(T, rhe.GetSigma())
# Out:
# 1000 1.0

# %% [markdown]
# # Rutter and Brodie, 2004, wet quartzite,

# %%
i      = 16
rock.iloc[i]
T      = np.arange(600,1200)+273
d      = 0
Coh    = 1000
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], Coh, 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
#rhe.plot_T_stress(T, rhe.GetSigma())
# Out:
# 1000 1.0

# %% [markdown]
# # Rutter and Brodie, 2004, wet quartzite, diffus...

# %%
i      = 17
rock.iloc[i]
T      = np.arange(600,1200)+273
d      = 10e3
Coh    = 100
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], Coh, 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
#rhe.plot_T_stress(T, rhe.GetSigma())
# Out:
# 100 10000.0

# %% [markdown]
# # Rybacki and Dresen 2006, wet An100 in dislocat

# %%
i      = 25
rock.iloc[i]
T      = np.arange(600,1200)+273
d      = 1
Coh    = 1000
strain = 1e-12
rhe    = rheology.flow_law(rock.A[i], rock.n[i], d, rock.m[i], Coh, 
                           rock.r[i], rock.Q[i], 1e9, rock.V[i], T, epsilon=strain)
rhe.plot_tempeature_viscosity(T, rhe.get_viscosity()*1e6)
#rhe.plot_T_stress(T, rhe.GetSigma())
# Out:
# 1000 1

# %%
rhe    = rheology.flow_law(90, 3.5, 1.0, 0.0, 1000, 1.2, 480e3, 1e9, 11e-6, 1673, sigma=0.3)
print(rhe.get_strain_rate())
# Out:
# 2.4748138964055293e-12

# %%
rhe    = rheology.flow_law(90*1e6, 3.5, 1.0, 0.0, 1000, 1.2, 480e3, 1e9, 11e-6, 1673, epsilon=2.47e-12)
print(f'{rhe.get_viscosity():e}')
# Out:
# 1000 1.0
# 1.171836e+15

# %%
print(f'{3000*10*100*1000:e}')
# Out:
# 3.000000e+09

# %%
print(f'{0.3*1e6/2.47e-12:e}')
# Out:
# 1.214575e+17

# %%
rhe    = rheology.flow_law(1e6, 1.0, 10000, 3, 1000, 1.0, 335e3, 1e9, 4e-6, 1673, sigma=0.3)
print(f'{rhe.get_strain_rate():e}')
print(f'{rhe.get_viscosity():e}')
# Out:
# 7.806090e-15
# 1000 10000
# 1.921577e+19
